# %% [markdown]
# # Lab: Python Data Analysis - First Steps
#
# In the following lab we will take our first steps in writing python code aimed for machine learning and data analysis.
# We will introduce the following python packages: `numpy`, `pandas`, `sklearn` and `plotnine`.
