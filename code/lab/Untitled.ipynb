# %%
import numpy as np

scores_mad = {
    7: [80, 64, ],
    6: [90, 76, 72, 85],
    5: [99, 81, 81, 97, 86, 93,  83],
    4: [78, 92, 95, 86],
    3: [89, 94, 90],
    2: [91, 94],
}

scores_stats = {
    7: [],
    6: [92],
    5: [],
    4: [90, 85, 94, 100],
    3: [100],
    2: []

}


others = {
    2:[74]
}


dicts = [scores_mad, scores_stats, others]


up = 0.0
down = 0.0
for k in scores_mad.keys():
    up += np.sum(k*np.array(scores_mad[k]))
    down += k*len(scores_mad[k])

for k in scores_stats.keys():
    up += np.sum(k*np.array(scores_stats[k]))
    down += k*len(scores_stats[k])

for k in others.keys():
    up += np.sum(k*np.array(others[k]))
    down += k*len(others[k])



    
print(up/down)
# Out:
# 86.16279069767442
